# %% [markdown]
# # USA Weather Analysis
# # Team Members
# ## 1)Kotta Sivaganesh
# ## 2)Dheeraj MS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("usa_weather_clean_data.csv")
df.head()
# Out:
#    Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                 0.00  03-01-2016           1             3       2016
# 1                 0.00  03-01-2016           1             3       2016
# 2                 0.16  03-01-2016           1             3       2016
# 3                 0.00  03-01-2016           1             3       2016
# 4                 0.01  03-01-2016           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                       39.0                       46.0
# 1                       39.0                       47.0
# ...

# %%
def degree_cal(temp):
    direction=None
    
    num=int(temp)
    if num==0:
        direction="North"
    elif num in [1, 2]:
        direction=" NNE (North-Northeast)"
    elif num in [3, 4]:
        direction=" NE (Northeast)"
    elif num in [5, 6]:
        direction=" ENE (East-Northeast)"
    elif num in [7, 8]:
        direction=" East"
    elif num in [9, 10]:
        direction=" ESE (East-Southeast)"
    elif num in [11, 12]:
        direction=" SE (Southeast)"
    elif num in [13, 14]:
        direction=" SSE (South-Southeast)"
    elif num in [15, 16]:
        direction=" South"
    elif num in [17, 18]:
        direction=" SSW (South-Southwest)"
    elif num in [19, 20]:
        direction=" SW (Southwest)"
    elif num in [21, 22]:
        direction=" WSW (West-Southwest)"
    elif num in [23, 24]:
        direction=" West"
    elif num in [25, 26]:
        direction=" WNW (West-Northwest)"
    elif num in [27, 28]:
        direction=" NW (Northwest)"
    elif num in [29, 30]:
        direction=" NNW (North-Northwest)"
    elif num in [31, 36]:
        direction=" North"
    return direction

# %%
# group by state and create a dictionary of dataframes
state_dfs = dict(tuple(df.groupby('Station.State')))

# %%
NewYork_df = state_dfs['New York']
NewYork_df
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 197                   0.01  03-01-2016           1             3       2016
# 198                   0.01  03-01-2016           1             3       2016
# 199                   0.13  03-01-2016           1             3       2016
# 200                   0.01  03-01-2016           1             3       2016
# 201                   0.00  03-01-2016           1             3       2016
# ...                    ...         ...         ...           ...        ...
# 16628                 0.69  01-01-2017           1             1       2017
# 16629                 0.67  01-01-2017           1             1       2017
# 16630                 0.48  01-01-2017           1             1       2017
# 16631                 0.22  01-01-2017           1             1       2017
# 16632                 0.43  01-01-2017           1             1       2017
#
# ...

# %%
print(f"""
the average temperature in NewYork_df is {NewYork_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {NewYork_df["Data.Temperature.Max Temp"].max()} to 
{NewYork_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {NewYork_df["Data.Precipitation "].median()} inches 
and max {NewYork_df["Data.Precipitation "].max()} inches 

average windspeed is {NewYork_df["Data.Wind.Speed"].median() } and 

wind direction is {NewYork_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(NewYork_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in NewYork_df is 51.0 F
#
# the temperature ranges from 93.0 to
# 5.0 F
#
# average rainfall is of 0.375 inches
# and max 4.93 inches
#
# average windspeed is 6.51 and
#
# wind direction is 21.0 which means most of the wind blows towards   WSW (West-Southwest)

# %%
Maine_df = state_dfs['Maine']
Maine_df
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 129                   0.00  03-01-2016           1             3       2016
# 130                   0.10  03-01-2016           1             3       2016
# 131                   0.01  03-01-2016           1             3       2016
# 444                   1.99  10-01-2016           1            10       2016
# 445                   0.52  10-01-2016           1            10       2016
# ...                    ...         ...         ...           ...        ...
# 16241                 0.10  25-12-2016          12            25       2016
# 16242                 0.22  25-12-2016          12            25       2016
# 16557                 1.73  01-01-2017           1             1       2017
# 16558                 1.89  01-01-2017           1             1       2017
# 16559                 2.10  01-01-2017           1             1       2017
#
# ...

# %%
print(f"""
the average temperature in Maine_df is {Maine_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Maine_df["Data.Temperature.Max Temp"].max()} to 
{Maine_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Maine_df["Data.Precipitation "].median()} inches 
and max {Maine_df["Data.Precipitation "].max()} inches 

average windspeed is {Maine_df["Data.Wind.Speed"].median() } and 

wind direction is {Maine_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Maine_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Maine_df is 45.0 F
#
# the temperature ranges from 89.0 to
# -2.0 F
#
# average rainfall is of 0.52 inches
# and max 4.28 inches
#
# average windspeed is 5.88 and
#
# wind direction is 22.0 which means most of the wind blows towards   WSW (West-Southwest)

# %%
NewHampshire_df = state_dfs['New Hampshire']
NewHampshire_df
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 190                   0.00  03-01-2016           1             3       2016
# 191                   0.00  03-01-2016           1             3       2016
# 505                   0.82  10-01-2016           1            10       2016
# 506                   0.00  10-01-2016           1            10       2016
# 820                   0.45  17-01-2016           1            17       2016
# ...                    ...         ...         ...           ...        ...
# 15985                 2.42  18-12-2016          12            18       2016
# 16301                 0.14  25-12-2016          12            25       2016
# 16302                 0.55  25-12-2016          12            25       2016
# 16618                 0.79  01-01-2017           1             1       2017
# 16619                 2.71  01-01-2017           1             1       2017
#
# ...

# %%
print(f"""
the average temperature in NewHampshire_df is {NewHampshire_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {NewHampshire_df["Data.Temperature.Max Temp"].max()} to 
{NewHampshire_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {NewHampshire_df["Data.Precipitation "].median()} inches 
and max {NewHampshire_df["Data.Precipitation "].max()} inches 

average windspeed is {NewHampshire_df["Data.Wind.Speed"].median() } and 

wind direction is {NewHampshire_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(NewHampshire_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in NewHampshire_df is 60.0 F
#
# the temperature ranges from 91.0 to
# -12.0 F
#
# average rainfall is of 0.11499999999999999 inches
# and max 3.79 inches
#
# average windspeed is 7.445 and
#
# wind direction is 24.0 which means most of the wind blows towards   West

# %% [markdown]
# Vermont

# %%
Vermont_df = state_dfs['Vermont']
Vermont_df
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 288                   0.03  03-01-2016           1             3       2016
# 603                   0.52  10-01-2016           1            10       2016
# 918                   0.20  17-01-2016           1            17       2016
# 1233                  0.34  24-01-2016           1            24       2016
# 1548                  0.10  31-01-2016           1            31       2016
# 1863                  0.24  07-02-2016           2             7       2016
# 2178                  0.14  14-02-2016           2            14       2016
# 2493                  0.67  21-02-2016           2            21       2016
# 2808                  2.09  28-02-2016           2            28       2016
# 3125                  0.25  06-03-2016           3             6       2016
# 3440                  0.49  13-03-2016           3            13       2016
# ...

# %%
print(f"""
the average temperature in Vermont_df is {Vermont_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Vermont_df["Data.Temperature.Max Temp"].max()} to 
{Vermont_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Vermont_df["Data.Precipitation "].median()} inches 
and max {Vermont_df["Data.Precipitation "].max()} inches 

average windspeed is {Vermont_df["Data.Wind.Speed"].median() } and 

wind direction is {Vermont_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Vermont_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Vermont_df is 49.0 F
#
# the temperature ranges from 87.0 to
# 5.0 F
#
# average rainfall is of 0.36 inches
# and max 2.09 inches
#
# average windspeed is 6.25 and
#
# wind direction is 23.0 which means most of the wind blows towards   West

# %% [markdown]
# # Massachusetts

# %%
Massachusetts_df = state_dfs['Massachusetts']
Massachusetts_df
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 134                   0.00  03-01-2016           1             3       2016
# 135                   0.00  03-01-2016           1             3       2016
# 136                   0.00  03-01-2016           1             3       2016
# 449                   1.39  10-01-2016           1            10       2016
# 450                   0.00  10-01-2016           1            10       2016
# ...                    ...         ...         ...           ...        ...
# 16246                 0.39  25-12-2016          12            25       2016
# 16247                 0.51  25-12-2016          12            25       2016
# 16562                 1.24  01-01-2017           1             1       2017
# 16563                 0.95  01-01-2017           1             1       2017
# 16564                 1.19  01-01-2017           1             1       2017
#
# ...

# %%
print(f"""
the average temperature in Massachusetts_df is {Massachusetts_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Massachusetts_df["Data.Temperature.Max Temp"].max()} to 
{Massachusetts_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Massachusetts_df["Data.Precipitation "].median()} inches 
and max {Massachusetts_df["Data.Precipitation "].max()} inches 

average windspeed is {Massachusetts_df["Data.Wind.Speed"].median() } and 

wind direction is {Massachusetts_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Massachusetts_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Massachusetts_df is 60.0 F
#
# the temperature ranges from 91.0 to
# 3.0 F
#
# average rainfall is of 0.2 inches
# and max 4.29 inches
#
# average windspeed is 8.48 and
#
# wind direction is 21.0 which means most of the wind blows towards   WSW (West-Southwest)

# %% [markdown]
# # Rhode Island

# %%
RhodeIsland_df = state_dfs['Rhode Island']
RhodeIsland_df.head()
# Out:
#       Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 244                  0.00  03-01-2016           1             3       2016
# 559                  1.41  10-01-2016           1            10       2016
# 874                  1.17  17-01-2016           1            17       2016
# 1189                 0.45  24-01-2016           1            24       2016
# 1504                 0.00  31-01-2016           1            31       2016
#
#      Station.City Station.Code Station.Location Station.State  \
# 244    Providence          PVD   Providence, RI  Rhode Island
# 559    Providence          PVD   Providence, RI  Rhode Island
# 874    Providence          PVD   Providence, RI  Rhode Island
# 1189   Providence          PVD   Providence, RI  Rhode Island
# 1504   Providence          PVD   Providence, RI  Rhode Island
#
#       Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 244                        36.0                       43.0
# ...

# %%
print(f"""
the average temperature in RhodeIsland_df is {RhodeIsland_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {RhodeIsland_df["Data.Temperature.Max Temp"].max()} to 
{RhodeIsland_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {RhodeIsland_df["Data.Precipitation "].median()} inches 
and max {RhodeIsland_df["Data.Precipitation "].max()} inches 

average windspeed is {RhodeIsland_df["Data.Wind.Speed"].median() } and 

wind direction is {RhodeIsland_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(RhodeIsland_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in RhodeIsland_df is 50.0 F
#
# the temperature ranges from 89.0 to
# 9.0 F
#
# average rainfall is of 0.45 inches
# and max 2.15 inches
#
# average windspeed is 6.65 and
#
# wind direction is 22.0 which means most of the wind blows towards   WSW (West-Southwest)

# %% [markdown]
# # Connecticut

# %%
Connecticut_df = state_dfs['Connecticut']
Connecticut_df.head()
# Out:
#      Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 68                  0.00  03-01-2016           1             3       2016
# 69                  0.00  03-01-2016           1             3       2016
# 383                 1.23  10-01-2016           1            10       2016
# 384                 1.46  10-01-2016           1            10       2016
# 698                 0.32  17-01-2016           1            17       2016
#
#       Station.City Station.Code   Station.Location Station.State  \
# 68      Bridgeport          BDR     Bridgeport, CT   Connecticut
# 69   Windsor Locks          BDL  Windsor Locks, CT   Connecticut
# 383     Bridgeport          BDR     Bridgeport, CT   Connecticut
# 384  Windsor Locks          BDL  Windsor Locks, CT   Connecticut
# 698     Bridgeport          BDR     Bridgeport, CT   Connecticut
#
#      Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 68                        38.0                       43.0
# ...

# %%
print(f"""
the average temperature in Connecticut_df is {Connecticut_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Connecticut_df["Data.Temperature.Max Temp"].max()} to 
{Connecticut_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Connecticut_df["Data.Precipitation "].median()} inches 
and max {Connecticut_df["Data.Precipitation "].max()} inches 

average windspeed is {Connecticut_df["Data.Wind.Speed"].median() } and 

wind direction is {Connecticut_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Connecticut_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Connecticut_df is 51.5 F
#
# the temperature ranges from 92.0 to
# 7.0 F
#
# average rainfall is of 0.39 inches
# and max 2.81 inches
#
# average windspeed is 6.02 and
#
# wind direction is 21.0 which means most of the wind blows towards   WSW (West-Southwest)

# %% [markdown]
# # New Jersey

# %%
NewJersey_df = state_dfs['New Jersey']
NewJersey_df.head()
# Out:
#      Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 192                 0.00  03-01-2016           1             3       2016
# 193                 0.00  03-01-2016           1             3       2016
# 507                 0.80  10-01-2016           1            10       2016
# 508                 1.78  10-01-2016           1            10       2016
# 822                 0.83  17-01-2016           1            17       2016
#
#       Station.City Station.Code   Station.Location Station.State  \
# 192  Atlantic City          ACY  Atlantic City, NJ    New Jersey
# 193         Newark          EWR         Newark, NJ    New Jersey
# 507  Atlantic City          ACY  Atlantic City, NJ    New Jersey
# 508         Newark          EWR         Newark, NJ    New Jersey
# 822  Atlantic City          ACY  Atlantic City, NJ    New Jersey
#
#      Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 192                       36.0                       46.0
# ...

# %%
print(f"""
the average temperature in NewJersey_df is {NewJersey_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {NewJersey_df["Data.Temperature.Max Temp"].max()} to 
{NewJersey_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {NewJersey_df["Data.Precipitation "].median()} inches 
and max {NewJersey_df["Data.Precipitation "].max()} inches 

average windspeed is {NewJersey_df["Data.Wind.Speed"].median() } and 

wind direction is {NewJersey_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(NewJersey_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in NewJersey_df is 54.0 F
#
# the temperature ranges from 93.0 to
# 18.0 F
#
# average rainfall is of 0.295 inches
# and max 4.85 inches
#
# average windspeed is 6.76 and
#
# wind direction is 20.0 which means most of the wind blows towards   SW (Southwest)

# %% [markdown]
# # Pennsylvania

# %%
Pennsylvania_df = state_dfs['Pennsylvania']
Pennsylvania_df.head()
# Out:
#      Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 236                 0.00  03-01-2016           1             3       2016
# 237                 0.31  03-01-2016           1             3       2016
# 238                 0.00  03-01-2016           1             3       2016
# 239                 0.00  03-01-2016           1             3       2016
# 240                 0.01  03-01-2016           1             3       2016
#
#      Station.City Station.Code  Station.Location Station.State  \
# 236     Allentown          ABE     Allentown, PA  Pennsylvania
# 237          Erie          ERI          Erie, PA  Pennsylvania
# 238    Harrisburg          MDT    Harrisburg, PA  Pennsylvania
# 239  Philadelphia          PHL  Philadelphia, PA  Pennsylvania
# 240    Pittsburgh          PIT    Pittsburgh, PA  Pennsylvania
#
#      Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 236                       34.0                       41.0
# ...

# %%
print(f"""
the average temperature in Pennsylvania_df is {Pennsylvania_df["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Pennsylvania_df["Data.Temperature.Max Temp"].max()} to 
{Pennsylvania_df["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Pennsylvania_df["Data.Precipitation "].median()} inches 
and max {Pennsylvania_df["Data.Precipitation "].max()} inches 

average windspeed is {Pennsylvania_df["Data.Wind.Speed"].median() } and 

wind direction is {Pennsylvania_df["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Pennsylvania_df["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Pennsylvania_df is 54.0 F
#
# the temperature ranges from 93.0 to
# 7.0 F
#
# average rainfall is of 0.35 inches
# and max 5.06 inches
#
# average windspeed is 5.45 and
#
# wind direction is 22.0 which means most of the wind blows towards   WSW (West-Southwest)

# %%
#making a data frame only for Northeastern states
frames=[NewYork_df,Pennsylvania_df,NewJersey_df,Connecticut_df,RhodeIsland_df,Massachusetts_df,Vermont_df,NewHampshire_df,Maine_df]

# %%
Northeastern_states=pd.concat(frames)

# %%
Northeastern_states
# Out:
#        Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 197                   0.01  03-01-2016           1             3       2016
# 198                   0.01  03-01-2016           1             3       2016
# 199                   0.13  03-01-2016           1             3       2016
# 200                   0.01  03-01-2016           1             3       2016
# 201                   0.00  03-01-2016           1             3       2016
# ...                    ...         ...         ...           ...        ...
# 16241                 0.10  25-12-2016          12            25       2016
# 16242                 0.22  25-12-2016          12            25       2016
# 16557                 1.73  01-01-2017           1             1       2017
# 16558                 1.89  01-01-2017           1             1       2017
# 16559                 2.10  01-01-2017           1             1       2017
#
# ...

# %%
print(f"""
the average temperature in Northeastern  States is {Northeastern_states["Data.Temperature.Avg Temp"].median()} F\n
the temperature ranges from {Northeastern_states["Data.Temperature.Max Temp"].max()} to 
{Northeastern_states["Data.Temperature.Min Temp"].min()} F \n
average rainfall is of {Northeastern_states["Data.Precipitation "].median()} inches 
and max {Northeastern_states["Data.Precipitation "].max()} inches 

average windspeed is {Northeastern_states["Data.Wind.Speed"].median() } and 

wind direction is {Northeastern_states["Data.Wind.Direction"].median()} which means most of the wind blows towards  {degree_cal(Northeastern_states["Data.Wind.Direction"].median())}

""")
# Out:
# the average temperature in Northeastern  States is 53.0 F
#
# the temperature ranges from 93.0 to
# -12.0 F
#
# average rainfall is of 0.35 inches
# and max 5.06 inches
#
# average windspeed is 6.4 and
#
# wind direction is 22.0 which means most of the wind blows towards   WSW (West-Southwest)

# %%
Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Avg Temp"].median()
# Out:
# Date.Month  Station.State
# 1           Connecticut      34.0
#             Maine            23.5
#             Massachusetts    34.0
#             New Hampshire    33.5
#             New Jersey       35.0
#                              ...
# 12          New Jersey       36.5
#             New York         31.0
#             Pennsylvania     32.5
#             Rhode Island     33.0
#             Vermont          28.5
# Name: Data.Temperature.Avg Temp, Length: 108, dtype: float64

# %%
result=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Avg Temp"].median()

# %%
Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Avg Temp"].median().reset_index()
# Out:
#      Date.Month  Station.State  Data.Temperature.Avg Temp
# 0             1    Connecticut                       34.0
# 1             1          Maine                       23.5
# 2             1  Massachusetts                       34.0
# 3             1  New Hampshire                       33.5
# 4             1     New Jersey                       35.0
# ..          ...            ...                        ...
# 103          12     New Jersey                       36.5
# 104          12       New York                       31.0
# 105          12   Pennsylvania                       32.5
# 106          12   Rhode Island                       33.0
# 107          12        Vermont                       28.5
#
# [108 rows x 3 columns]

# %%
ans=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Avg Temp"].median().reset_index()

# %%
# Analysing southern states each month which state has average lowest temperature
for month in ans['Date.Month'].unique():  # iterate over unique months
    month_df = ans[ans['Date.Month'] == month]  # filter data for current month
    min_temp = month_df['Data.Temperature.Avg Temp'].min()  # find min temp for current month
    states_with_min_temp = month_df.loc[month_df['Data.Temperature.Avg Temp'] == min_temp, 'Station.State']  # get states with min temp
    for state in states_with_min_temp:
        print(f"Month: {month}, State: {state}, Temperature: {min_temp}")
# Out:
# Month: 1, State: Maine, Temperature: 23.5
# Month: 2, State: Maine, Temperature: 25.5
# Month: 3, State: Maine, Temperature: 29.5
# Month: 4, State: Maine, Temperature: 41.0
# Month: 5, State: New York, Temperature: 53.0
# Month: 6, State: Massachusetts, Temperature: 60.5
# Month: 7, State: New Hampshire, Temperature: 63.0
# Month: 8, State: New Hampshire, Temperature: 62.5
# Month: 9, State: New Hampshire, Temperature: 62.0
# Month: 10, State: Maine, Temperature: 52.0
# Month: 11, State: Maine, Temperature: 40.5
# Month: 12, State: New Hampshire, Temperature: 19.5

# %%
# Analysing southern states each month which state has average Highest temperature
for month in ans['Date.Month'].unique():  # iterate over unique months
    month_df = ans[ans['Date.Month'] == month]  # filter data for current month
    max_temp = month_df['Data.Temperature.Avg Temp'].max()  # find max temp for current month
    states_with_max_temp = month_df.loc[month_df['Data.Temperature.Avg Temp'] == max_temp, 'Station.State']  # get states with min temp
    for state in states_with_min_temp:
        print(f"Month: {month}, State: {state}, Temperature: {max_temp}")
# Out:
# Month: 1, State: New Hampshire, Temperature: 35.0
# Month: 2, State: New Hampshire, Temperature: 47.0
# Month: 3, State: New Hampshire, Temperature: 48.5
# Month: 4, State: New Hampshire, Temperature: 56.5
# Month: 5, State: New Hampshire, Temperature: 60.0
# Month: 6, State: New Hampshire, Temperature: 70.0
# Month: 7, State: New Hampshire, Temperature: 79.5
# Month: 8, State: New Hampshire, Temperature: 79.0
# Month: 9, State: New Hampshire, Temperature: 71.0
# Month: 10, State: New Hampshire, Temperature: 60.5
# Month: 11, State: New Hampshire, Temperature: 53.0
# Month: 12, State: New Hampshire, Temperature: 36.5

# %%
for month in ans['Date.Month'].unique():  # iterate over unique months
    month_df = ans[ans['Date.Month'] == month]  # filter data for current month
    min_temp = month_df['Data.Temperature.Avg Temp'].min()  # find min temp for current month
    states_with_min_temp = month_df.loc[month_df['Data.Temperature.Avg Temp'] == min_temp, 'Station.State']  # get states with min temp
    for state in states_with_min_temp.values:
        print(f"Month: {month}, State: {state}, Temperature: {min_temp}")
# Out:
# Month: 1, State: Maine, Temperature: 23.5
# Month: 2, State: Maine, Temperature: 25.5
# Month: 3, State: Maine, Temperature: 29.5
# Month: 4, State: Maine, Temperature: 41.0
# Month: 5, State: New York, Temperature: 53.0
# Month: 6, State: Massachusetts, Temperature: 60.5
# Month: 7, State: New Hampshire, Temperature: 63.0
# Month: 8, State: New Hampshire, Temperature: 62.5
# Month: 9, State: New Hampshire, Temperature: 62.0
# Month: 10, State: Maine, Temperature: 52.0
# Month: 11, State: Maine, Temperature: 40.5
# Month: 12, State: New Hampshire, Temperature: 19.5

# %% [markdown]
# # which states have lowest temperature in

# %%
low_df=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Min Temp"].median().reset_index()

# %%
low_df
# Out:
#      Date.Month  Station.State  Data.Temperature.Min Temp
# 0             1    Connecticut                       24.5
# 1             1          Maine                       15.0
# 2             1  Massachusetts                       26.0
# 3             1  New Hampshire                       26.5
# 4             1     New Jersey                       26.0
# ..          ...            ...                        ...
# 103          12     New Jersey                       28.5
# 104          12       New York                       25.5
# 105          12   Pennsylvania                       26.5
# 106          12   Rhode Island                       25.5
# 107          12        Vermont                       22.5
#
# [108 rows x 3 columns]

# %%
for month in low_df['Date.Month'].unique():  # iterate over unique months
    month_df = low_df[low_df['Date.Month'] == month]  # filter data for current month
    min_temp = month_df['Data.Temperature.Min Temp'].min()  # find min temp for current month
    states_with_min_temp = month_df.loc[month_df['Data.Temperature.Min Temp'] == min_temp, 'Station.State']  # get states with min temp
    for state in states_with_min_temp.values:
        print(f"Month: {month}, State: {state}, Temperature: {min_temp}")
# Out:
# Month: 1, State: Maine, Temperature: 15.0
# Month: 2, State: Maine, Temperature: 14.0
# Month: 3, State: Maine, Temperature: 20.5
# Month: 4, State: Maine, Temperature: 29.5
# Month: 5, State: Maine, Temperature: 43.0
# Month: 6, State: New Hampshire, Temperature: 51.0
# Month: 7, State: Maine, Temperature: 58.0
# Month: 8, State: New Hampshire, Temperature: 52.5
# Month: 9, State: Maine, Temperature: 51.5
# Month: 10, State: Maine, Temperature: 39.0
# Month: 11, State: Maine, Temperature: 30.5
# Month: 12, State: New Hampshire, Temperature: 11.0

# %% [markdown]
# # which states have highest temperature in NE

# %%
high_df=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Temperature.Max Temp"].median().reset_index()

# %%
high_df
# Out:
#      Date.Month  Station.State  Data.Temperature.Max Temp
# 0             1    Connecticut                       42.0
# 1             1          Maine                       33.5
# 2             1  Massachusetts                       41.0
# 3             1  New Hampshire                       40.5
# 4             1     New Jersey                       44.0
# ..          ...            ...                        ...
# 103          12     New Jersey                       45.0
# 104          12       New York                       36.5
# 105          12   Pennsylvania                       40.5
# 106          12   Rhode Island                       40.5
# 107          12        Vermont                       34.0
#
# [108 rows x 3 columns]

# %%
for month in high_df['Date.Month'].unique():  # iterate over unique months
    month_df = high_df[high_df['Date.Month'] == month]  # filter data for current month
    min_temp = month_df['Data.Temperature.Max Temp'].max()  # find min temp for current month
    states_with_min_temp = month_df.loc[month_df['Data.Temperature.Max Temp'] == min_temp, 'Station.State']  # get states with min temp
    for state in states_with_min_temp.values:
        print(f"Month: {month}, State: {state}, Temperature: {min_temp}")
# Out:
# Month: 1, State: New Jersey, Temperature: 44.0
# Month: 2, State: New Hampshire, Temperature: 53.0
# Month: 3, State: New Jersey, Temperature: 57.5
# Month: 4, State: New Jersey, Temperature: 62.0
# Month: 4, State: Pennsylvania, Temperature: 62.0
# Month: 5, State: Rhode Island, Temperature: 69.0
# Month: 6, State: New Jersey, Temperature: 82.0
# Month: 6, State: Pennsylvania, Temperature: 82.0
# Month: 7, State: New Jersey, Temperature: 87.0
# Month: 7, State: Pennsylvania, Temperature: 87.0
# Month: 8, State: New Jersey, Temperature: 88.0
# Month: 9, State: Pennsylvania, Temperature: 81.0
# Month: 10, State: New Jersey, Temperature: 66.5
# Month: 11, State: New Hampshire, Temperature: 59.5
# Month: 11, State: New Jersey, Temperature: 59.5
# Month: 12, State: New Jersey, Temperature: 45.0

# %% [markdown]
# # which state has most rainfall month wise

# %%
max_rain_df=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Precipitation "].max().reset_index()

# %%
max_rain_df
# Out:
#      Date.Month  Station.State  Data.Precipitation
# 0             1    Connecticut                 1.46
# 1             1          Maine                 2.11
# 2             1  Massachusetts                 1.40
# 3             1  New Hampshire                 2.71
# 4             1     New Jersey                 1.88
# ..          ...            ...                  ...
# 103          12     New Jersey                 1.38
# 104          12       New York                 1.94
# 105          12   Pennsylvania                 2.16
# 106          12   Rhode Island                 1.08
# 107          12        Vermont                 1.05
#
# [108 rows x 3 columns]

# %%
for month in max_rain_df["Date.Month"].unique():
    month_df = max_rain_df[max_rain_df["Date.Month"] == month]
    max_rain = month_df['Data.Precipitation '].max()
    states_with_max_rain = month_df.loc[month_df['Data.Precipitation '] == max_rain, 'Station.State']
    for state in states_with_max_rain.values:
        print(f"Month: {month}, State: {state}, Maximum Rain: {max_rain}")
# Out:
# Month: 1, State: Pennsylvania, Maximum Rain: 2.76
# Month: 2, State: Pennsylvania, Maximum Rain: 3.16
# Month: 3, State: New Jersey, Maximum Rain: 1.72
# Month: 4, State: Rhode Island, Maximum Rain: 2.12
# Month: 5, State: New Jersey, Maximum Rain: 2.57
# Month: 6, State: Maine, Maximum Rain: 2.45
# Month: 7, State: New Jersey, Maximum Rain: 4.85
# Month: 8, State: Pennsylvania, Maximum Rain: 5.06
# Month: 9, State: Pennsylvania, Maximum Rain: 2.66
# Month: 10, State: New York, Maximum Rain: 4.93
# Month: 11, State: New Jersey, Maximum Rain: 3.22
# Month: 12, State: New Hampshire, Maximum Rain: 2.43

# %%
rain_df=Northeastern_states.groupby(['Date.Month','Station.State'])["Data.Precipitation "].median().reset_index()

# %%
rain_df
# Out:
#      Date.Month  Station.State  Data.Precipitation
# 0             1    Connecticut                0.360
# 1             1          Maine                0.225
# 2             1  Massachusetts                0.090
# 3             1  New Hampshire                0.000
# 4             1     New Jersey                0.355
# ..          ...            ...                  ...
# 103          12     New Jersey                0.585
# 104          12       New York                0.525
# 105          12   Pennsylvania                0.590
# 106          12   Rhode Island                0.380
# 107          12        Vermont                0.375
#
# [108 rows x 3 columns]

# %%
#finding the highest averages using max()
for month in rain_df["Date.Month"].unique():
    month_df = rain_df[max_rain_df["Date.Month"] == month]
    max_rain = month_df['Data.Precipitation '].max()
    states_with_max_rain = month_df.loc[month_df['Data.Precipitation '] == max_rain, 'Station.State']
    for state in states_with_max_rain.values:
        print(f"Month: {month}, State: {state}, Maximum Rain: {max_rain}")
# Out:
# Month: 1, State: Rhode Island, Maximum Rain: 0.78
# Month: 2, State: New Jersey, Maximum Rain: 1.385
# Month: 3, State: Maine, Maximum Rain: 0.78
# Month: 4, State: Rhode Island, Maximum Rain: 0.73
# Month: 5, State: Vermont, Maximum Rain: 0.51
# Month: 6, State: Vermont, Maximum Rain: 0.475
# Month: 7, State: New Jersey, Maximum Rain: 0.825
# Month: 8, State: Rhode Island, Maximum Rain: 0.845
# Month: 9, State: Connecticut, Maximum Rain: 0.49
# Month: 10, State: Rhode Island, Maximum Rain: 0.9
# Month: 11, State: Maine, Maximum Rain: 0.655
# Month: 12, State: New Hampshire, Maximum Rain: 1.0350000000000001

# %%
Northeastern_states.to_csv("Northeastern_states.csv",index=False)

# %%
ne=pd.read_csv("Northeastern_states.csv",index_col="Date.Full")

# %%
ne
# Out:
#             Data.Precipitation   Date.Month  Date.Week of  Date.Year  \
# Date.Full
# 03-01-2016                 0.01           1             3       2016
# 03-01-2016                 0.01           1             3       2016
# 03-01-2016                 0.13           1             3       2016
# 03-01-2016                 0.01           1             3       2016
# 03-01-2016                 0.00           1             3       2016
# ...                         ...         ...           ...        ...
# 25-12-2016                 0.10          12            25       2016
# 25-12-2016                 0.22          12            25       2016
# 01-01-2017                 1.73           1             1       2017
# 01-01-2017                 1.89           1             1       2017
# 01-01-2017                 2.10           1             1       2017
#
#            Station.City Station.Code Station.Location Station.State  \
# Date.Full
# ...

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=ne["Data.Precipitation "])
plt.xticks(rotation=90)
plt.show()

# %%
#new try
plt.figure(figsize=(10,3))
sns.lineplot(data=ne["Data.Temperature.Avg Temp"])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.lineplot(data=ne,x="Date.Month",y=ne["Data.Temperature.Avg Temp"])
plt.show()

# %%
df_wide = ne.pivot_table(index="Date.Month", columns="Station.State", values="Data.Temperature.Avg Temp")

# %%
df_wide
# Out:
# Station.State  Connecticut      Maine  Massachusetts  New Hampshire  \
# Date.Month
# 1                32.833333  23.500000      39.222222      39.916667
# 2                32.750000  23.500000      40.833333      43.625000
# 3                43.375000  30.083333      46.750000      42.600000
# 4                47.750000  39.750000      45.666667      51.875000
# 5                57.100000  53.400000      56.733333      57.300000
# 6                66.625000  61.333333      62.750000      62.000000
# 7                76.200000  70.000000      69.066667      65.800000
# 8                77.125000  69.416667      74.500000      62.125000
# 9                70.250000  63.250000      66.083333      61.750000
# 10               56.000000  49.333333      55.733333      55.800000
# 11               46.500000  39.916667      46.111111      51.000000
# 12               35.125000  22.583333      32.500000      18.500000
#
# ...

# %%
plt.figure(figsize=(10,3))
sns.lineplot(data=df_wide)
# Out:
# <Axes: xlabel='Date.Month'>

# %%
plt.figure(figsize=(10,3))
sns.lineplot(data=df_wide["New York"])
sns.lineplot(data=df_wide["Maine"])
plt.title("New York temperature")
plt.ylabel("Temperature")
plt.xlabel("Months")
# Out:
# Text(0.5, 0, 'Months')

# %%
for state in df_wide:
    print(f"{state}->{df_wide[state].mean().round(2)}")
# Out:
# Connecticut->53.47
# Maine->45.51
# Massachusetts->53.0
# New Hampshire->51.02
# New Jersey->56.12
# New York->51.06
# Pennsylvania->53.94
# Rhode Island->53.08
# Vermont->49.1
