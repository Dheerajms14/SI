# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
midwest_df = pd.read_csv('midwest_states.csv')
midwest_df
# Out:
#       Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  03-01-2016           1             3       2016
# 1                    0.00  03-01-2016           1             3       2016
# 2                    0.00  03-01-2016           1             3       2016
# 3                    0.00  03-01-2016           1             3       2016
# 4                    0.00  03-01-2016           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 3758                 0.34  25-12-2016          12            25       2016
# 3759                 0.35  01-01-2017           1             1       2017
# 3760                 0.04  01-01-2017           1             1       2017
# 3761                 0.11  01-01-2017           1             1       2017
# 3762                 0.15  01-01-2017           1             1       2017
#
#      Station.City Station.Code Station.Location Station.State  \
# ...

# %%
northeast_df = pd.read_csv('northeastern_states.csv')
northeast_df
# Out:
#       Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.01  03-01-2016           1             3       2016
# 1                    0.01  03-01-2016           1             3       2016
# 2                    0.13  03-01-2016           1             3       2016
# 3                    0.01  03-01-2016           1             3       2016
# 4                    0.00  03-01-2016           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 1520                 0.10  25-12-2016          12            25       2016
# 1521                 0.22  25-12-2016          12            25       2016
# 1522                 1.73  01-01-2017           1             1       2017
# 1523                 1.89  01-01-2017           1             1       2017
# 1524                 2.10  01-01-2017           1             1       2017
#
#      Station.City Station.Code Station.Location Station.State  \
# ...

# %%
south_df = pd.read_csv('southern_states.csv')
south_df
# Out:
#       Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  03-01-2016           1             3       2016
# 1                    0.00  03-01-2016           1             3       2016
# 2                    0.00  03-01-2016           1             3       2016
# 3                    0.00  03-01-2016           1             3       2016
# 4                    0.53  10-01-2016           1            10       2016
# ...                   ...         ...         ...           ...        ...
# 5393                 0.00  25-12-2016          12            25       2016
# 5394                 0.51  01-01-2017           1             1       2017
# 5395                 1.57  01-01-2017           1             1       2017
# 5396                 1.72  01-01-2017           1             1       2017
# 5397                 0.62  01-01-2017           1             1       2017
#
#      Station.City Station.Code Station.Location  Station.State  \
# ...

# %%
west_df = pd.read_csv('western_states.csv')  # Assuming this file also exists
west_df
# Out:
#       Data.Precipitation    Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  03-01-2016           1             3       2016
# 1                    0.00  03-01-2016           1             3       2016
# 2                    0.02  03-01-2016           1             3       2016
# 3                    0.37  10-01-2016           1            10       2016
# 4                    0.27  10-01-2016           1            10       2016
# ...                   ...         ...         ...           ...        ...
# 5893                 0.00  01-01-2017           1             1       2017
# 5894                 0.00  01-01-2017           1             1       2017
# 5895                 0.17  01-01-2017           1             1       2017
# 5896                 0.00  01-01-2017           1             1       2017
# 5897                 1.40  01-01-2017           1             1       2017
#
# ...

# %%
df.columns
# Out:
# Index(['Data.Precipitation ', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt


midwest_df = pd.read_csv('midwest_states.csv')
northeast_df = pd.read_csv('northeastern_states.csv')
south_df = pd.read_csv('southern_states.csv')
west_df = pd.read_csv('western_states.csv')  

avg_midwest_precipitation = midwest_df['Data.Precipitation '].mean()
avg_northeast_precipitation = northeast_df['Data.Precipitation '].mean()
avg_south_precipitation = south_df['Data.Precipitation '].mean()
avg_west_precipitation = west_df['Data.Precipitation '].mean()


regions = ['Midwest', 'Northeast', 'South', 'West']
average_precipitations = [
    avg_midwest_precipitation, 
    avg_northeast_precipitation, 
    avg_south_precipitation, 
    avg_west_precipitation
]


plt.figure(figsize=(10, 6))
plt.bar(regions, average_precipitations, color=['blue', 'green', 'red', 'purple'])
plt.title('Average Data.Precipitation by Region')
plt.xlabel('Region')
plt.ylabel('Average Precipitation')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


midwest_df = pd.read_csv('midwest_states.csv')
northeast_df = pd.read_csv('northeastern_states.csv')
south_df = pd.read_csv('southern_states.csv')
west_df = pd.read_csv('western_states.csv')  


avg_midwest_tem = midwest_df['Data.Temperature.Avg Temp'].mean()
avg_northeast_tem = northeast_df['Data.Temperature.Avg Temp'].mean()
avg_south_tem = south_df['Data.Temperature.Avg Temp'].mean()
avg_west_tem = west_df['Data.Temperature.Avg Temp'].mean()


regions = ['Midwest', 'Northeast', 'South', 'West']
average_temp = [
    avg_midwest_tem, 
    avg_northeast_tem, 
    avg_south_tem, 
    avg_west_tem
]


plt.figure(figsize=(10, 6))
plt.bar(regions, average_temp, color=['blue', 'green', 'red', 'purple'])
plt.title('Data.Temperature.Avg Temp by Region')
plt.xlabel('Region')
plt.ylabel('average_temp')


plt.show()

# %%
avg_west_tem = west_df['Data.Temperature.Avg Temp'].mean()
avg_west_tem
# Out:
# 51.59240420481519

# %%
avg_west_precipitation = west_df['Data.Precipitation '].mean()
avg_west_precipitation
# Out:
# 0.41687690742624617

# %%
import pandas as pd
import matplotlib.pyplot as plt

midwest_df = pd.read_csv('midwest_states.csv')
northeast_df = pd.read_csv('northeastern_states.csv')
south_df = pd.read_csv('southern_states.csv')
west_df = pd.read_csv('western_states.csv')  


Max_midwest_tem = midwest_df['Data.Temperature.Max Temp'].mean()
Max_northeast_tem = northeast_df['Data.Temperature.Max Temp'].mean()
Max_south_tem = south_df['Data.Temperature.Max Temp'].mean()
Max_west_tem = west_df['Data.Temperature.Max Temp'].mean()

regions = ['Midwest', 'Northeast', 'South', 'West']
Max_temp = [
    Max_midwest_tem, 
    Max_northeast_tem, 
    Max_south_tem, 
    Max_west_tem
]

plt.figure(figsize=(10, 6))
plt.bar(regions, Max_temp, color=['blue', 'green', 'red', 'purple'])
plt.title('Data.Temperature.Max Temp by Region')
plt.xlabel('Region')
plt.ylabel('Max_temp')


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

midwest_df = pd.read_csv('midwest_states.csv')
northeast_df = pd.read_csv('northeastern_states.csv')
south_df = pd.read_csv('southern_states.csv')
west_df = pd.read_csv('western_states.csv')  

Min_midwest_tem = midwest_df['Data.Temperature.Min Temp'].mean()
Min_northeast_tem = northeast_df['Data.Temperature.Min Temp'].mean()
Min_south_tem = south_df['Data.Temperature.Min Temp'].mean()
Min_west_tem = west_df['Data.Temperature.Min Temp'].mean()

regions = ['Midwest', 'Northeast', 'South', 'West']
Min_temp = [
    Min_midwest_tem, 
    Min_northeast_tem, 
    Min_south_tem, 
    Min_west_tem
]

plt.figure(figsize=(10, 6))
plt.bar(regions, Min_temp, color=['blue', 'green', 'red', 'purple'])
plt.title('Data.Temperature.Min Temp by Region')
plt.xlabel('Region')
plt.ylabel('Min_temp')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

midwest_df = pd.read_csv('midwest_states.csv')
northeast_df = pd.read_csv('northeastern_states.csv')
south_df = pd.read_csv('southern_states.csv')
west_df = pd.read_csv('western_states.csv')  # Assuming this file also exists

wind_midwest = midwest_df['Data.Wind.Speed'].mean()
wind_northeast = northeast_df['Data.Wind.Speed'].mean()
wind_south = south_df['Data.Wind.Speed'].mean()
wind_west = west_df['Data.Wind.Speed'].mean()

regions = ['Midwest', 'Northeast', 'South', 'West']
Wind_speed = [
    wind_midwest, 
    wind_northeast, 
    wind_south, 
    wind_west
]

plt.figure(figsize=(10, 6))
plt.bar(regions, Wind_speed, color=['blue', 'green', 'red', 'purple'])
plt.title('Wind Speed by Region')
plt.xlabel('Region')
plt.ylabel('Wind_speed')

plt.show()
